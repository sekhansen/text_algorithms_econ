# %% [markdown]
# # **BERT Extensions**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sekhansen/text_algorithms_econ/blob/main/notebooks/5a_bert_extensions.ipynb)

# %% [markdown]
# This notebook will develop two additional applications of BERT. Concretely, we will show how to use a model trained specifically to identify similar sentences
# ([*Sentence BERT*](https://www.sbert.net/index.html)) and a model trained for sentimen analysis ([Twitter roBERTa](https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment)).

# %% [markdown]
# # 0. Setup

# %%
# Instructions for Colab: 
# 1. First CHANGE RUNTIME TYPE to GPU 
# 2. Then run install commands commented out below
# 3. You might need to RESTART RUNTIME
# 4. Run the rest of the cells below

# %%
# # install required libraries
# !pip3 install transformers                  # HuggingFace library for interacting with BERT (and multiple other models)
# !pip3 install datasets                      # HuggingFace library to process dataframes
# !pip3 install sentence-transformers         # library to use Sentence Similarity BERT
# !pip3 install bertviz                       # visualize BERT's attention weigths
# !pip3 install annoy                         # Spotify's library for finding nearest neighbours
# !pip3 install pyyaml==5.4.1                 # required for plotly express (interactive plots)                     
# !pip3 install ipywidgets

# %%
# (COLAB) you might need to restart RUNTIME after installing packages!

# %%
import pandas as pd
import numpy as np
import gdown
import random
from tqdm.auto import tqdm
import time
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import torch
from annoy import AnnoyIndex
from scipy import spatial

from transformers import BertModel, AutoTokenizer, BertForSequenceClassification, pipeline, TrainingArguments, Trainer, utils
from transformers.pipelines.base import KeyDataset
from datasets import load_dataset, load_metric, Dataset, DatasetDict

from sentence_transformers import SentenceTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# test GPU
print(f"GPU: {torch.cuda.is_available()}")
# Out:
# GPU: True

# %%
# define dictionary with paths to data in Google Drive
urls_dict = {"10k_sent_2019":        ("https://drive.google.com/uc?id=17PQbZ6EotMxyhpt2Laqqh9z-EKUbwDhX", "parquet"),
             "covariates_2019":      ("https://drive.google.com/uc?id=1ELRq69FOiFvNpSvXOijGeGKZB5DiNXt4", "csv"),
             "naics2_codes":         ("https://drive.google.com/uc?id=1H4bFNVbEbhxQotoxsM3yf-JrtgKGXG0k", "csv")
            }

# %%
# download each file in the dictionary
for file_name, attributes in urls_dict.items():
    url = attributes[0]
    extension = attributes[1]
    gdown.download(url, f"{file_name}.{extension}", quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17PQbZ6EotMxyhpt2Laqqh9z-EKUbwDhX
# To: /content/10k_sent_2019.parquet
# 100%|██████████| 162M/162M [00:02<00:00, 73.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ELRq69FOiFvNpSvXOijGeGKZB5DiNXt4
# To: /content/covariates_2019.csv
# 100%|██████████| 428k/428k [00:00<00:00, 54.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1H4bFNVbEbhxQotoxsM3yf-JrtgKGXG0k
# To: /content/naics2_codes.csv
# 100%|██████████| 868/868 [00:00<00:00, 2.13MB/s]

# %% [markdown]
# # 1. Load data

# %%
# read data
df = pd.read_parquet("10k_sent_2019.parquet")
df
# Out:
#                                                  sentences      cik  year  \
# 0        You should carefully review the following disc...  1065088  2019
# 1        Risk Factors That May Affect our Business, Res...  1065088  2019
# 2        Our operating and financial results are subjec...  1065088  2019
# 3        Our operating and financial results have varie...  1065088  2019
# 4        It is difficult for us to forecast the level o...  1065088  2019
# ...                                                    ...      ...   ...
# 1744126                                                     1069533  2019
# 1744127  The Company is generally isolated from commodi...  1069533  2019
# 1744128                                                     1069533  2019
# 1744129  With respect to interest rate risk, the Compan...  1069533  2019
# 1744130  However, increases in interest rates could adv...  1069533  2019
#
#          sent_no      sent_id
# 0              0    1065088_0
# 1              1    1065088_1
# 2              2    1065088_2
# 3              3    1065088_3
# 4              4    1065088_4
# ...          ...          ...
# 1744126      189  1069533_189
# 1744127      190  1069533_190
# 1744128      191  1069533_191
# 1744129      192  1069533_192
# 1744130      193  1069533_193
#
# [1744131 rows x 5 columns]

# %%
# firm-level additional data
covariates = pd.read_csv("covariates_2019.csv")
covariates.head()
# Out:
#    gvkey  datadate  fyear indfmt consol popsrc datafmt   tic  \
# 0   1004  20200531   2019   INDL      C      D     STD   AIR
# 1   1050  20191231   2019   INDL      C      D     STD  CECE
# 2   1078  20191231   2019   INDL      C      D     STD   ABT
# 3   1104  20191231   2019   INDL      C      D     STD   ACU
# 4   1117  20191231   2019   INDL      C      D     STD  BKTI
#
#                       conm curcd        act         at      emp   cik costat  \
# 0                 AAR CORP   USD   1438.700   2079.000    5.400  1750      A
# 1  CECO ENVIRONMENTAL CORP   USD    179.498    408.637    0.830  3197      A
# 2      ABBOTT LABORATORIES   USD  15667.000  67887.000  107.000  1800      A
# 3         ACME UNITED CORP   USD     73.146    110.749    0.441  2098      A
# 4     BK TECHNOLOGIES CORP   USD     23.886     37.940    0.111  2186      A
#
#     naics  naics2      naics2_name
# 0  423860      42  Wholesale Trade
# 1  333413      33    Manufacturing
# 2  334510      33    Manufacturing
# 3  332215      33    Manufacturing
# 4  334220      33    Manufacturing

# %%
# we will choose some specific firms of interest using their TIC identifiers
tics = ["AAPL", "GOOGL", "TWTR", "ORCL", "TSLA", "GM", "F", "BAC", 
        "COF", "JPM", "AXP", "HBC2", "TGT", "M", "WMT", "COST", 
        "BNED", "DIS", "FOXA", "ADSK", "CAT", "BA"]

# subset covariates
covariates_focus = covariates.loc[covariates["tic"].isin(tics)]
covariates_focus = covariates_focus.groupby("tic", as_index=False).max()
covariates_focus
# Out:
#       tic   gvkey  datadate  fyear indfmt consol popsrc datafmt  \
# 0    AAPL    1690  20190930   2019   INDL      C      D     STD
# 1    ADSK    1878  20200131   2019   INDL      C      D     STD
# 2     AXP    1447  20191231   2019   INDL      C      D     STD
# 3      BA    2285  20191231   2019   INDL      C      D     STD
# 4     BAC    7647  20191231   2019   INDL      C      D     STD
# 5    BNED   23208  20200430   2019   INDL      C      D     STD
# 6     CAT    2817  20191231   2019   INDL      C      D     STD
# 7     COF   30990  20191231   2019   INDL      C      D     STD
# 8    COST   29028  20190831   2019   INDL      C      D     STD
# 9     DIS    3980  20190930   2019   INDL      C      D     STD
# 10      F    4839  20191231   2019   INDL      C      D     STD
# 11   FOXA   34636  20190630   2019   INDL      C      D     STD
# 12     GM    5073  20191231   2019   INDL      C      D     STD
# 13  GOOGL  160329  20191231   2019   INDL      C      D     STD
# 14   HBC2    9061  20191231   2019   INDL      C      D     STD
# 15    JPM    2968  20191231   2019   INDL      C      D     STD
# 16      M    4611  20200131   2019   INDL      C      D     STD
# 17   ORCL   12142  20200531   2019   INDL      C      D     STD
# 18    TGT    3813  20200131   2019   INDL      C      D     STD
# 19   TSLA  184996  20191231   2019   INDL      C      D     STD
# 20   TWTR   18872  20191231   2019   INDL      C      D     STD
# 21    WMT   11259  20200131   2019   INDL      C      D     STD
#
#                             conm curcd         act           at       emp  \
# 0                      APPLE INC   USD  162819.000   338516.000   137.000
# 1                   AUTODESK INC   USD    2659.300     6179.300    10.100
# 2            AMERICAN EXPRESS CO   USD         NaN   198321.000    64.500
# 3                      BOEING CO   USD  102229.000   133625.000   161.100
# 4           BANK OF AMERICA CORP   USD         NaN  2434079.000   208.131
# 5   BARNES & NOBLE EDUCATION INC   USD     584.919     1156.432     5.500
# 6                CATERPILLAR INC   USD   39193.000    78453.000   102.300
# 7     CAPITAL ONE FINANCIAL CORP   USD         NaN   390365.000    51.900
# 8          COSTCO WHOLESALE CORP   USD   23485.000    45400.000   254.000
# 9               DISNEY (WALT) CO   USD   28124.000   193984.000   223.000
# 10                 FORD MOTOR CO   USD  114047.000   258537.000   190.000
# 11                      FOX CORP   USD    6478.000    19509.000     7.700
# 12             GENERAL MOTORS CO   USD   74992.000   228037.000   164.000
# 13                  ALPHABET INC   USD  152578.000   275909.000   118.899
# 14                  HSBC USA INC   USD         NaN   175375.000     4.828
# 15           JPMORGAN CHASE & CO   USD         NaN  2687379.000   256.981
# 16                    MACY'S INC   USD    6810.000    21172.000   123.000
# 17                   ORACLE CORP   USD   52140.000   115438.000   135.000
# 18                   TARGET CORP   USD   12902.000    42779.000   368.000
# 19                     TESLA INC   USD   12103.000    34309.000    48.016
# 20                   TWITTER INC   USD    7620.075    12703.389     4.900
# 21                   WALMART INC   USD   61806.000   236495.000  2200.000
#
#         cik costat   naics  naics2            naics2_name
# 0    320193      A  334220      33          Manufacturing
# 1    769397      A  519130      51            Information
# 2      4962      A  522210      52  Finance and Insurance
# 3     12927      A  336411      33          Manufacturing
# 4     70858      A  522110      52  Finance and Insurance
# 5   1634117      A  451211      45           Retail Trade
# 6     18230      A  333120      33          Manufacturing
# 7    927628      A  522210      52  Finance and Insurance
# 8    909832      A  452311      45           Retail Trade
# 9   1744489      A  515120      51            Information
# 10    37996      A   33611      33          Manufacturing
# 11  1754301      A  515120      51            Information
# 12  1467858      A   33611      33          Manufacturing
# 13  1652044      A  518210      51            Information
# 14    83246      A  522110      52  Finance and Insurance
# 15    19617      A  522110      52  Finance and Insurance
# 16   794367      A  452210      45           Retail Trade
# 17  1341439      A  519130      51            Information
# 18    27419      A  452319      45           Retail Trade
# 19  1318605      A  336111      33          Manufacturing
# 20  1418091      A  519130      51            Information
# 21   104169      A  452319      45           Retail Trade

# %%
# generate a dictionary mapping from CIK to name
cik2name = {row["cik"]: row["conm"] for i, row in covariates_focus.iterrows()}
cik2name
# Out:
# {320193: 'APPLE INC',
#  769397: 'AUTODESK INC',
#  4962: 'AMERICAN EXPRESS CO',
#  12927: 'BOEING CO',
#  70858: 'BANK OF AMERICA CORP',
#  1634117: 'BARNES & NOBLE EDUCATION INC',
#  18230: 'CATERPILLAR INC',
#  927628: 'CAPITAL ONE FINANCIAL CORP',
#  909832: 'COSTCO WHOLESALE CORP',
#  1744489: 'DISNEY (WALT) CO',
#  37996: 'FORD MOTOR CO',
#  1754301: 'FOX CORP',
#  1467858: 'GENERAL MOTORS CO',
#  1652044: 'ALPHABET INC',
#  83246: 'HSBC USA INC',
#  19617: 'JPMORGAN CHASE & CO',
#  794367: "MACY'S INC",
#  1341439: 'ORACLE CORP',
#  27419: 'TARGET CORP',
#  1318605: 'TESLA INC',
#  1418091: 'TWITTER INC',
#  104169: 'WALMART INC'}

# %%
# select the 10K reports from the choosen firms only
df = df.loc[df["cik"].isin(covariates_focus["cik"])]
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                               sentences      cik  year  \
# 0     The following discussion sets forth the materi...    19617  2019
# 1     Readers should not consider any descriptions o...    19617  2019
# 2     Any of the risk factors discussed below could ...    19617  2019
# 3                                            Regulatory    19617  2019
# 4     JPMorgan Chase's businesses are highly regulat...    19617  2019
# ...                                                 ...      ...   ...
# 7279  With the completion of the TFCF acquisition, o...  1744489  2019
# 7280  The increased indebtedness could have the effe...  1744489  2019
# 7281  The increased levels of indebtedness could als...  1744489  2019
# 7282  repurchases and dividends, and other activitie...  1744489  2019
# 7283  Our financial flexibility may be further const...  1744489  2019
#
#       sent_no      sent_id
# 0           0      19617_0
# 1           1      19617_1
# 2           2      19617_2
# 3           3      19617_3
# 4           4      19617_4
# ...       ...          ...
# 7279      194  1744489_194
# 7280      195  1744489_195
# 7281      196  1744489_196
# 7282      197  1744489_197
# 7283      198  1744489_198
#
# [7284 rows x 5 columns]

# %%
# lets explore a random sentence from our corpus
i = np.random.randint(0, len(df))
print(f"Sentence from: {cik2name[df.loc[i, 'cik']]}\n")
print(df.loc[i, "sentences"])
# Out:
# Sentence from: BARNES & NOBLE EDUCATION INC
#
# If colleges and universities, faculty and students are not receptive to our new products and services or our new products and services do not meet the expectations of these constituencies, there could be a negative impact on the implementation of our strategy.

# %%
# merge each sentence with the NAICS2 code from its corresponding firm
df = pd.merge(df, covariates_focus[["cik", "naics2"]], how="left", on="cik")
df
# Out:
#                                               sentences      cik  year  \
# 0     The following discussion sets forth the materi...    19617  2019
# 1     Readers should not consider any descriptions o...    19617  2019
# 2     Any of the risk factors discussed below could ...    19617  2019
# 3                                            Regulatory    19617  2019
# 4     JPMorgan Chase's businesses are highly regulat...    19617  2019
# ...                                                 ...      ...   ...
# 7279  With the completion of the TFCF acquisition, o...  1744489  2019
# 7280  The increased indebtedness could have the effe...  1744489  2019
# 7281  The increased levels of indebtedness could als...  1744489  2019
# 7282  repurchases and dividends, and other activitie...  1744489  2019
# 7283  Our financial flexibility may be further const...  1744489  2019
#
#       sent_no      sent_id  naics2
# 0           0      19617_0      52
# 1           1      19617_1      52
# 2           2      19617_2      52
# 3           3      19617_3      52
# 4           4      19617_4      52
# ...       ...          ...     ...
# 7279      194  1744489_194      51
# 7280      195  1744489_195      51
# 7281      196  1744489_196      51
# 7282      197  1744489_197      51
# 7283      198  1744489_198      51
#
# [7284 rows x 6 columns]

# %%
# drop empty sentences or sentences with very few words
min_words = 3
df["sentence_len"] = df["sentences"].apply(lambda x: len(x.split()))
df["keep_sent"] = df["sentence_len"].apply(lambda x: x > min_words)
df = df.loc[df["keep_sent"]]
df.reset_index(drop=True, inplace=True)
df
# Out:
#                                               sentences      cik  year  \
# 0     The following discussion sets forth the materi...    19617  2019
# 1     Readers should not consider any descriptions o...    19617  2019
# 2     Any of the risk factors discussed below could ...    19617  2019
# 3     JPMorgan Chase's businesses are highly regulat...    19617  2019
# 4     JPMorgan Chase is a financial services firm wi...    19617  2019
# ...                                                 ...      ...   ...
# 6793  With the completion of the TFCF acquisition, o...  1744489  2019
# 6794  The increased indebtedness could have the effe...  1744489  2019
# 6795  The increased levels of indebtedness could als...  1744489  2019
# 6796  repurchases and dividends, and other activitie...  1744489  2019
# 6797  Our financial flexibility may be further const...  1744489  2019
#
#       sent_no      sent_id  naics2  sentence_len  keep_sent
# 0           0      19617_0      52            18       True
# 1           1      19617_1      52            23       True
# 2           2      19617_2      52            53       True
# 3           4      19617_4      52            25       True
# 4           5      19617_5      52            10       True
# ...       ...          ...     ...           ...        ...
# 6793      194  1744489_194      51            19       True
# 6794      195  1744489_195      51            22       True
# 6795      196  1744489_196      51            14       True
# 6796      197  1744489_197      51            21       True
# 6797      198  1744489_198      51            23       True
#
# [6798 rows x 8 columns]

# %%
# lastly we will load the names of the NAICS2 codes
df_naics = pd.read_csv("naics2_codes.csv")
df_naics
# Out:
#     Sector                                        Description
# 0       11  Agriculture, Forestry, Fishing and Hunting (no...
# 1       21      Mining, Quarrying, and Oil and Gas Extraction
# 2       22                                          Utilities
# 3       23                                       Construction
# 4       31                                      Manufacturing
# 5       32                                      Manufacturing
# 6       33                                      Manufacturing
# 7       42                                    Wholesale Trade
# 8       44                                       Retail Trade
# 9       45                                       Retail Trade
# 10      48                     Transportation and Warehousing
# 11      49                     Transportation and Warehousing
# 12      51                                        Information
# 13      52                              Finance and Insurance
# 14      53                 Real Estate and Rental and Leasing
# 15      54   Professional, Scientific, and Technical Services
# 16      55            Management of Companies and Enterprises
# 17      56  Administrative and Support and Waste Managemen...
# 18      61                               Educational Services
# 19      62                  Health Care and Social Assistance
# 20      71                Arts, Entertainment, and Recreation
# 21      72                    Accommodation and Food Services
# 22      81      Other Services (except Public Administration)
# 23      92  Public Administration (not covered in economic...

# %%
# transform dataframe into Dataset class (easier to work with pipeline)
dataset = Dataset.from_pandas(df)
dataset
# Out:
# Dataset({
#     features: ['sentences', 'cik', 'year', 'sent_no', 'sent_id', 'naics2', 'sentence_len', 'keep_sent'],
#     num_rows: 6798
# })

# %% [markdown]
# # 2. Sentence similarity
#
# We will start by exploring [*Sentence BERT*](https://www.sbert.net/index.html).

# %%
# load sentence embedding model from Huggingface
# list of all available models here: https://www.sbert.net/docs/pretrained_models.html
model_sent = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
model_sent
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 384, 'do_lower_case': False}) with Transformer model: MPNetModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# )

# %%
# test the model by embedding two similar sentences
sent_a = "We are highly exposed to volatility from the currency markets."
sent_b = "Our firm holds multiple currencies and can be affected by fluctuations in that market."
sent_emb_a = model_sent.encode(sent_a)
sent_emb_b = model_sent.encode(sent_b)
print(sent_emb_a.shape, sent_emb_b.shape)

# calculate the cosine similarity between the two embedded representations
cos_sim = 1- spatial.distance.cosine(sent_emb_a, sent_emb_b)
print(f"Cosine similarity between sentences: {cos_sim}")
# Out:
# (768,) (768,)
# Cosine similarity between sentences: 0.6639918088912964

# %%
# test the model by embedding two different sentences
sent_a = "We are highly exposed to volatility from the currency markets."
sent_b = "Our sales have grown constantly each quarter."
sent_emb_a = model_sent.encode(sent_a)
sent_emb_b = model_sent.encode(sent_b)
print(sent_emb_a.shape, sent_emb_b.shape)

# calculate the cosine similarity between the two embedded representations
cos_sim = 1- spatial.distance.cosine(sent_emb_a, sent_emb_b)
print(f"Cosine similarity between sentences: {cos_sim}")
# Out:
# (768,) (768,)
# Cosine similarity between sentences: 0.28047850728034973

# %%
# get embedded representations for all sequences (takes a couple of minutes)
all_sent_emb = []
for sent in tqdm(df["sentences"].values):
    all_sent_emb.append(model_sent.encode(sent))

all_sent_emb = np.array(all_sent_emb)
# Out:
#   0%|          | 0/6798 [00:00<?, ?it/s]

# %%
def build_indexer(vectors, num_trees=10):
    """ we will use a version of approximate nearest neighbors
        (ANNOY: https://github.com/spotify/annoy) to build an indexer
        of the sequence embeddings matrix
    """
    
    # angular = cosine
    indexer = AnnoyIndex(vectors.shape[1], 'angular')
    for i, vec in enumerate(vectors):
        # add word embedding to indexer
        indexer.add_item(i, vec)
        
    # build trees for searching
    indexer.build(num_trees)
    
    return indexer

# %%
# create an indexer for all our estimated sentence embeddings
indexer_emb = build_indexer(all_sent_emb, 1000)

# %%
# select a random sentence
sent_position = 23
sent = df.loc[sent_position, "sentences"]
print(sent)
# Out:
# The content and application of laws and regulations affecting financial services firms sometimes vary according to factors such as the size of the firm, the jurisdiction in which it is organized or operates, and other criteria.

# %%
# find the top-n nearest neighbours to the target sequence
cls_nns, cls_dists = indexer_emb.get_nns_by_item(sent_position, n=5, include_distances=True)

# print results
for nn_idx, dist in zip(cls_nns, cls_dists):
    print(f"Cosine similarity between sentence and target: {1- dist}")
    print(df.loc[nn_idx, "sentences"])
    print("\n-------\n")
# Out:
# Cosine similarity between sentence and target: 1.0
# The content and application of laws and regulations affecting financial services firms sometimes vary according to factors such as the size of the firm, the jurisdiction in which it is organized or operates, and other criteria.
#
# -------
#
# Cosine similarity between sentence and target: 0.2770317792892456
# In many countries, the laws and regulations applicable to the financial services and securities industries are uncertain and evolving, and it may be difficult for us to determine the exact requirements of local laws in every market or manage our relationships with multiple regulators in various jurisdictions.
#
# -------
#
# Cosine similarity between sentence and target: 0.26296287775039673
# However, regulatory focus is not limited to laws and regulations applicable to the financial services industry specifically, but also extends to other significant laws and regulations that apply across industries and jurisdictions,
#
# -------
#
# Cosine similarity between sentence and target: 0.2476828694343567
# These laws and regulations may not apply in the same manner to all financial institutions, and we therefore may face more restrictions than other institutions and companies with which we compete for talent.
#
# -------
#
# Cosine similarity between sentence and target: 0.2314673662185669
# The Company is subject to a variety of regulations in the jurisdictions in which its businesses operate.
#
# -------

# %%
# the target sentence does not have to be in the corpus!
outside_target = "We are highly exposed to volatility from the currency markets."
outside_emb = model_sent.encode(outside_target)

# %%
# find the top-n nearest neighbours to the target sequence
out_nns, out_dists = indexer_emb.get_nns_by_vector(outside_emb, n=6, include_distances=True)

# print results
for nn_idx, dist in zip(out_nns, out_dists):
    print(f"Cosine similarity between sentence and target: {1- dist}")
    print(df.loc[nn_idx, "sentences"])
    print("\n-------\n")
# Out:
# Cosine similarity between sentence and target: 0.19929510354995728
# Volatility in global financial markets may also limit our ability to access the capital markets at a time when we would like, or need, to raise capital, which could have an impact on our ability to react to changing economic and business conditions.
#
# -------
#
# Cosine similarity between sentence and target: 0.187941312789917
# • fluctuating currency exchange rates, including devaluations, currency controls and inflation, and risks related to any hedging activities we undertake;
#
# -------
#
# Cosine similarity between sentence and target: 0.18664461374282837
# We may experience foreign currency gains and losses.
#
# -------
#
# Cosine similarity between sentence and target: 0.1817135214805603
# We are exposed to fluctuations in currency exchange rates, which could negatively affect our financial results.
#
# -------
#
# Cosine similarity between sentence and target: 0.1802622675895691
# As we continue to expand internationally, our exposure to fluctuations in foreign exchange rates may increase.
#
# -------
#
# Cosine similarity between sentence and target: 0.1714128851890564
# Increased market volatility and adverse changes in other financial or capital market conditions may increase our market risk.
#
# -------

# %% [markdown]
# ## Most similar firms
#
# We could take this analysis one step further and generate an embedded representation for each firm based on all its sentences and then find the firms with the most similar representations.

# %%
all_sent_emb.shape, df.shape
# Out:
# ((6798, 768), (6798, 8))

# %%
# build a dataframe with the features obtained using sentence embeddings
df_features_sent = pd.DataFrame(all_sent_emb)
df_features_sent
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.011817  0.011453  0.011278  0.009599  0.065816  0.051294 -0.011161
# 1    -0.015233  0.028815 -0.017432  0.037591  0.011595  0.017166  0.074671
# 2    -0.026442  0.026214 -0.006620 -0.005092  0.050608  0.063110 -0.018622
# 3     0.034214  0.044039 -0.002761 -0.032364  0.057897  0.008970  0.007638
# 4     0.032164 -0.006661  0.018511 -0.026890  0.028302  0.027686  0.031307
# ...        ...       ...       ...       ...       ...       ...       ...
# 6793  0.000095 -0.016173  0.020436  0.010461  0.015649  0.013981 -0.072255
# 6794  0.015674  0.042853 -0.034396 -0.071674  0.045786  0.023405 -0.035900
# 6795  0.010755  0.018237 -0.019800  0.002902  0.049219  0.012570 -0.049772
# 6796  0.031607  0.026091 -0.004579 -0.045578  0.029132  0.030749 -0.002315
# 6797  0.059045 -0.031188 -0.018785 -0.007732  0.063012  0.017999 -0.009497
#
#            7         8         9    ...       758       759       760  \
# 0    -0.001203 -0.057753  0.001920  ... -0.077610  0.002371  0.051753
# 1     0.019215  0.021796  0.001575  ... -0.051599 -0.022396 -0.082621
# 2     0.018449 -0.065425  0.005702  ... -0.055689 -0.000722  0.031532
# 3     0.011436 -0.006285 -0.004822  ... -0.063936  0.027796  0.062791
# 4     0.016948  0.002818  0.038235  ... -0.086915  0.010322  0.093289
# ...        ...       ...       ...  ...       ...       ...       ...
# 6793  0.024676 -0.000678 -0.053130  ... -0.093776 -0.001394 -0.017165
# 6794  0.061967  0.032311 -0.014177  ... -0.018045  0.001670 -0.003966
# 6795  0.037785 -0.020872 -0.006634  ... -0.058688  0.007294 -0.029078
# 6796  0.037723 -0.034652 -0.037827  ... -0.063526  0.005702  0.021538
# 6797  0.072563 -0.063375 -0.032754  ... -0.012851 -0.005232 -0.017692
#
#            761       762       763       764       765       766       767
# 0     0.024290 -0.015564 -0.135904  0.020548  0.015652 -0.004299 -0.036282
# 1    -0.046256 -0.049867 -0.082608 -0.019138 -0.001914  0.022236 -0.038196
# 2     0.036150 -0.040938 -0.099203  0.032251 -0.003874  0.019218 -0.042799
# 3    -0.002406 -0.001966 -0.093930 -0.019117  0.032081  0.028137 -0.006739
# 4     0.011004 -0.016153 -0.121062  0.027341  0.011709  0.011302 -0.025043
# ...        ...       ...       ...       ...       ...       ...       ...
# 6793  0.031219  0.020396  0.021740  0.031515 -0.017126 -0.063337  0.023777
# 6794  0.043865 -0.007955 -0.034968  0.076045 -0.014369 -0.014035 -0.030880
# 6795  0.049130 -0.020713 -0.038941  0.062150 -0.039018 -0.025081  0.005752
# 6796  0.040555 -0.027343 -0.042495  0.013669 -0.056975  0.009584 -0.041691
# 6797  0.059463  0.006822 -0.019927  0.039954  0.025305 -0.026583  0.004323
#
# [6798 rows x 768 columns]

# %%
# generate the average embedding for each firm
df_complete = pd.merge(df[["cik"]], df_features_sent, left_index=True, right_index=True)
df_complete = df_complete.groupby("cik").mean()
df_complete
# Out:
#               0         1         2         3         4         5         6    \
# cik
# 4962     0.019879  0.026010 -0.019184 -0.018643  0.014444  0.020973  0.008990
# 12927    0.015298  0.044881 -0.014579 -0.018776  0.010792  0.006025  0.016023
# 18230    0.010052  0.033827 -0.019514 -0.019296  0.013930  0.013427  0.006527
# 19617    0.020168  0.014061 -0.008622 -0.022687  0.018320  0.015482  0.024413
# 27419    0.011948  0.038824 -0.024521 -0.013707  0.003803  0.014576  0.011898
# 37996   -0.004353  0.018064 -0.016329 -0.003626  0.012887  0.006649  0.013223
# 70858    0.010090  0.010388 -0.021029 -0.027153  0.012916  0.022050  0.007205
# 83246    0.010535  0.009517 -0.017550 -0.028471  0.006697  0.022102  0.002504
# 104169   0.015948  0.033207 -0.020680 -0.016498  0.005827  0.019717  0.022917
# 320193   0.013581  0.019667 -0.018069 -0.023280  0.000161  0.015253  0.020193
# 769397   0.018936  0.034858 -0.021511 -0.018010 -0.001992  0.010705  0.017588
# 794367   0.014557  0.045859 -0.023164 -0.015958  0.010190  0.017224  0.011797
# 909832   0.012621  0.039931 -0.020980 -0.013285  0.012525  0.017318  0.011301
# 927628   0.018116  0.020081 -0.021275 -0.024276  0.015123  0.019535  0.009123
# 1318605  0.022516  0.024509 -0.016629 -0.004300  0.020310  0.010899  0.013795
# 1341439  0.026176  0.032658 -0.021077 -0.020049  0.000858  0.012104  0.018330
# 1418091  0.037361  0.025964 -0.018284 -0.023055  0.001581  0.011016  0.019064
# 1467858  0.011706  0.028841 -0.016745 -0.006819  0.008950  0.007491  0.015794
# 1634117  0.033825  0.026834 -0.015095 -0.016941  0.001460  0.011590  0.026511
# 1652044  0.032222  0.032538 -0.018549 -0.018801 -0.002763  0.009304  0.021673
# 1744489  0.025231  0.032946 -0.018277 -0.018354  0.006293  0.012986  0.016691
# 1754301  0.011936  0.024772 -0.004304 -0.027386  0.001366  0.019085  0.009061
#
#               7         8         9    ...       758       759       760  \
# cik                                    ...
# 4962     0.006543 -0.005482 -0.009186  ... -0.024711 -0.001085  0.011852
# 12927   -0.004752 -0.019452 -0.014558  ... -0.022867 -0.005490  0.003285
# 18230    0.001290 -0.000190 -0.002489  ... -0.023403 -0.004944  0.005346
# 19617    0.020393  0.007186  0.007695  ... -0.059663  0.027477  0.017301
# 27419   -0.013777 -0.010525 -0.018194  ... -0.012937 -0.001486  0.000917
# 37996    0.010724 -0.009883 -0.017637  ... -0.021504  0.003767  0.015866
# 70858    0.008445  0.001109 -0.002382  ... -0.034996 -0.003046  0.010050
# 83246    0.008346  0.004776 -0.000584  ... -0.032057  0.001436  0.000963
# 104169  -0.008693 -0.006521 -0.020892  ... -0.016673  0.005593  0.002620
# 320193  -0.000907 -0.006477 -0.018088  ... -0.027148  0.006282  0.004441
# 769397  -0.004168 -0.007661 -0.010003  ... -0.026625 -0.002736  0.002291
# 794367  -0.008357 -0.013500 -0.020055  ... -0.012910 -0.005077  0.000650
# 909832  -0.006426 -0.004134 -0.014042  ... -0.013651 -0.000149 -0.000390
# 927628   0.002927  0.000191 -0.006641  ... -0.026716  0.000739  0.008357
# 1318605 -0.001484 -0.019503 -0.012468  ... -0.020766 -0.001817  0.013944
# 1341439 -0.005595 -0.005201 -0.010473  ... -0.021372  0.001323  0.010581
# 1418091 -0.008418  0.001456 -0.016957  ... -0.019000  0.000061  0.001221
# 1467858  0.003375 -0.009897 -0.019207  ... -0.023457 -0.002223  0.013710
# 1634117 -0.004560 -0.003958 -0.020330  ... -0.026632  0.004662  0.003097
# 1652044 -0.005317  0.005288 -0.023047  ... -0.025020 -0.002536  0.007904
# 1744489  0.001018 -0.014318 -0.018260  ... -0.018656  0.001406 -0.001474
# 1754301  0.012144 -0.005316 -0.021420  ... -0.018679 -0.007559 -0.007752
#
#               761       762       763       764       765       766       767
# cik
# 4962     0.025457 -0.007650 -0.028705 -0.005007 -0.000991 -0.004378 -0.018492
# 12927    0.022536  0.004924 -0.033322 -0.005269  0.005829 -0.015184 -0.020776
# 18230    0.024811  0.000083 -0.037911 -0.003992  0.002600 -0.015587 -0.013797
# 19617    0.006711 -0.007842 -0.046338  0.002647  0.009555 -0.011538 -0.004290
# 27419    0.025584 -0.002680 -0.023530 -0.021586 -0.004050 -0.001755 -0.024600
# 37996    0.018362  0.003664 -0.011600 -0.014517  0.000610 -0.019705 -0.017020
# 70858    0.029529 -0.001939 -0.032610  0.000155  0.000581 -0.017796 -0.011413
# 83246    0.026662 -0.003242 -0.030859 -0.001764  0.002341 -0.025424 -0.011769
# 104169   0.026011 -0.000965 -0.037308 -0.016959 -0.004356 -0.018325 -0.023024
# 320193   0.019986 -0.007399 -0.019781 -0.006536 -0.004269 -0.006209 -0.023301
# 769397   0.022128 -0.000374 -0.013368 -0.007920 -0.005602 -0.010153 -0.019838
# 794367   0.024462 -0.003318 -0.023593 -0.008808 -0.006002 -0.009218 -0.028338
# 909832   0.026531  0.002257 -0.026831 -0.009899 -0.002695 -0.014330 -0.021104
# 927628   0.026171 -0.004875 -0.024213 -0.000799 -0.000337 -0.012849 -0.016826
# 1318605  0.021515  0.002990 -0.012054 -0.014238 -0.005776 -0.020112 -0.024563
# 1341439  0.021268  0.003658 -0.017981 -0.008366 -0.006725 -0.008044 -0.018724
# 1418091  0.022977  0.002694 -0.007157 -0.011730  0.001614 -0.002927 -0.014723
# 1467858  0.019274  0.007633 -0.031685 -0.013264 -0.006012 -0.018142 -0.024718
# 1634117  0.017077 -0.002689 -0.011280 -0.011795 -0.004494 -0.009249 -0.022486
# 1652044  0.022551  0.003287 -0.013917 -0.013324 -0.006106 -0.004361 -0.017145
# 1744489  0.018634  0.004920 -0.025869 -0.011423 -0.005225 -0.005834 -0.011281
# 1754301  0.006312 -0.001334 -0.021331 -0.009166  0.000920 -0.005987 -0.015953
#
# [22 rows x 768 columns]

# %%
# transform features into numpy array
firm_features = df_complete.to_numpy()
firm_features.shape
# Out:
# (22, 768)

# %%
# create an indexer for the firm embeddings
indexer_firms = build_indexer(firm_features, 1000)

# %%
idx2name = {i: cik2name[code] for i,code in enumerate(list(df_complete.index))}
idx2name
# Out:
# {0: 'AMERICAN EXPRESS CO',
#  1: 'BOEING CO',
#  2: 'CATERPILLAR INC',
#  3: 'JPMORGAN CHASE & CO',
#  4: 'TARGET CORP',
#  5: 'FORD MOTOR CO',
#  6: 'BANK OF AMERICA CORP',
#  7: 'HSBC USA INC',
#  8: 'WALMART INC',
#  9: 'APPLE INC',
#  10: 'AUTODESK INC',
#  11: "MACY'S INC",
#  12: 'COSTCO WHOLESALE CORP',
#  13: 'CAPITAL ONE FINANCIAL CORP',
#  14: 'TESLA INC',
#  15: 'ORACLE CORP',
#  16: 'TWITTER INC',
#  17: 'GENERAL MOTORS CO',
#  18: 'BARNES & NOBLE EDUCATION INC',
#  19: 'ALPHABET INC',
#  20: 'DISNEY (WALT) CO',
#  21: 'FOX CORP'}

# %%
# find the top-n nearest neighbours to the target sequence
target_firm = 5
firm_nns, firm_dists = indexer_firms.get_nns_by_item(target_firm, n=4, include_distances=True)

# print results
print(f"NNs to: {idx2name[target_firm]} \n\n")
for i, (nn_idx, dist) in enumerate(zip(firm_nns, firm_dists)):
    if i > 0:
        print(idx2name[nn_idx])
        print(f"Cosine similarity between firms: {1 - dist}")
        print("\n-------")
# Out:
# NNs to: FORD MOTOR CO
#
#
# GENERAL MOTORS CO
# Cosine similarity between firms: 0.6480782330036163
#
# -------
# TESLA INC
# Cosine similarity between firms: 0.5675284266471863
#
# -------
# CATERPILLAR INC
# Cosine similarity between firms: 0.5275600850582123
#
# -------

# %%
#%%

# we can also use a dimension reduction technique to plot these embedded
# representation of firms in 2 dimensions

#==================
# PCA
#==================

pca = PCA(n_components=2)
pca.fit(firm_features)
features_pca = pca.transform(firm_features)
print(f"Variance explained by each component: {pca.explained_variance_}")

#%%

#==================
# TSNE
#==================

features_tsne = TSNE(n_components=2,
                    perplexity=2,
                    learning_rate='auto', 
                    init='random', 
                    metric="cosine").fit_transform(firm_features)


# consolidate features in a single dataframe
df_plot = pd.DataFrame({"cik": df_complete.index, "firm_name": idx2name.values(),
                        "pca1": features_pca[:, 0], "pca2": features_pca[:, 1],
                        "tsne1": features_tsne[:, 0], "tsne2": features_tsne[:, 1]
                        })

# join with NAICS2 data
df_plot = pd.merge(df_plot, df[["cik", "naics2"]], on="cik", how="left")
df_plot["naics2_name"] = df_plot["naics2"].apply(lambda x: df_naics.loc[df_naics["Sector"] == x]["Description"].values[0])
df_plot
# Out:
# Variance explained by each component: [0.00989373 0.00645536]
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:827: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   FutureWarning,
#           cik            firm_name      pca1      pca2      tsne1      tsne2  \
# 0        4962  AMERICAN EXPRESS CO  0.057503 -0.022319 -38.096714  60.729584
# 1        4962  AMERICAN EXPRESS CO  0.057503 -0.022319 -38.096714  60.729584
# 2        4962  AMERICAN EXPRESS CO  0.057503 -0.022319 -38.096714  60.729584
# 3        4962  AMERICAN EXPRESS CO  0.057503 -0.022319 -38.096714  60.729584
# 4        4962  AMERICAN EXPRESS CO  0.057503 -0.022319 -38.096714  60.729584
# ...       ...                  ...       ...       ...        ...        ...
# 6793  1754301             FOX CORP  0.020748 -0.100219 -24.729893 -61.772484
# 6794  1754301             FOX CORP  0.020748 -0.100219 -24.729893 -61.772484
# 6795  1754301             FOX CORP  0.020748 -0.100219 -24.729893 -61.772484
# 6796  1754301             FOX CORP  0.020748 -0.100219 -24.729893 -61.772484
# 6797  1754301             FOX CORP  0.020748 -0.100219 -24.729893 -61.772484
#
#       naics2            naics2_name
# 0         52  Finance and Insurance
# 1         52  Finance and Insurance
# 2         52  Finance and Insurance
# 3         52  Finance and Insurance
# 4         52  Finance and Insurance
# ...      ...                    ...
# 6793      51            Information
# 6794      51            Information
# 6795      51            Information
# 6796      51            Information
# 6797      51            Information
#
# [6798 rows x 8 columns]

# %%
# PCA plot
plt.figure(figsize=(12,8))
sns.scatterplot(data=df_plot, x="pca1", y="pca2", 
                hue="naics2_name", s=100,
                palette=['green','orange','brown','dodgerblue'])

plt.xlabel("PCA component 1")
plt.ylabel("PCA component 2")
plt.show()

# %%
# t-SNE plot
plt.figure(figsize=(12,8))
sns.scatterplot(data=df_plot, x="tsne1", y="tsne2",
                hue="naics2_name", s=100,
                palette=['green','orange','brown','dodgerblue'])

plt.xlabel("component 1")
plt.ylabel("component 2")
plt.tight_layout()
plt.legend(title="Sector",  fontsize="medium", fancybox=True)
plt.show()

# %%
# interactive 2D plot
fig = px.scatter(df_plot, x="tsne1", y="tsne2", color="naics2_name", hover_data=['cik', "firm_name"], color_discrete_sequence=['green','orange','brown','dodgerblue'])
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="db6efe6f-129d-4c1f-9295-c69ddf8abcc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db6efe6f-129d-4c1f-9295-c69ddf8abcc3")) {                    Plotly.newPlot(                        "db6efe6f-129d-4c1f-9295-c69ddf8abcc3",                        [{"customdata":[[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN EXPRESS CO"],[4962,"AMERICAN  ...

# %% [markdown]
# # 3. Sentiment analysis
#
# We will use a model trained on Twitter data to predict if a tweet had a negative, neutral or positive sentiment. The model is available through HuggingFace [here](https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment) and we will load it using: *cardiffnlp/twitter-roberta-base-sentiment*.

# %%
# generate sentiment prediction using a pipeline object for text classification
sentiment_classifier = pipeline(task="text-classification",                                 # define the task
                                model="cardiffnlp/twitter-roberta-base-sentiment",          # model should be appropriate for the task
                                tokenizer="cardiffnlp/twitter-roberta-base-sentiment",      # selected tokenizer
                                batch_size=16,                                              # batching only supported for GPUs
                                device=0,                                                   # -1 for CPU and 0 for GPU
                                framework="pt"                                              # data type 
                                )                

sentiment_classifier.task
# Out:
# Downloading config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/476M [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# 'text-classification'

# %%
# classify all sequences (save their label and the score)
all_sentiment_labels = []
all_scores = []
for out in tqdm(sentiment_classifier(KeyDataset(dataset, "sentences"),
                                     truncation=True, 
                                     max_length=60,
                                     padding=False)):
    
    # extract the label and the score for each prediction
    all_sentiment_labels.append(out["label"])
    all_scores.append(out["score"])
# Out:
#   0%|          | 0/425 [00:00<?, ?it/s]

# %%
# add predictions to dataframe
df["sentiment_label"] = all_sentiment_labels
df["sentiment_label_score"] = all_scores
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                               sentences      cik  year  \
# 0     The following discussion sets forth the materi...    19617  2019
# 1     Readers should not consider any descriptions o...    19617  2019
# 2     Any of the risk factors discussed below could ...    19617  2019
# 3     JPMorgan Chase's businesses are highly regulat...    19617  2019
# 4     JPMorgan Chase is a financial services firm wi...    19617  2019
# ...                                                 ...      ...   ...
# 6793  With the completion of the TFCF acquisition, o...  1744489  2019
# 6794  The increased indebtedness could have the effe...  1744489  2019
# 6795  The increased levels of indebtedness could als...  1744489  2019
# 6796  repurchases and dividends, and other activitie...  1744489  2019
# 6797  Our financial flexibility may be further const...  1744489  2019
#
#       sent_no      sent_id  naics2  sentence_len  keep_sent sentiment_label  \
# 0           0      19617_0      52            18       True         LABEL_1
# 1           1      19617_1      52            23       True         LABEL_0
# 2           2      19617_2      52            53       True         LABEL_0
# 3           4      19617_4      52            25       True         LABEL_1
# 4           5      19617_5      52            10       True         LABEL_1
# ...       ...          ...     ...           ...        ...             ...
# 6793      194  1744489_194      51            19       True         LABEL_1
# 6794      195  1744489_195      51            22       True         LABEL_0
# 6795      196  1744489_196      51            14       True         LABEL_0
# 6796      197  1744489_197      51            21       True         LABEL_0
# 6797      198  1744489_198      51            23       True         LABEL_1
#
#       sentiment_label_score
# 0                  0.770769
# 1                  0.656604
# 2                  0.733676
# 3                  0.765478
# 4                  0.869748
# ...                     ...
# 6793               0.943793
# 6794               0.579556
# 6795               0.585248
# 6796               0.583103
# 6797               0.565884
#
# [6798 rows x 10 columns]

# %%
# search for the sentences with the highest NEGATIVE scores (LABEL_0)
df_neg = df.loc[df["sentiment_label"] == "LABEL_0"].copy()
df_neg.sort_values("sentiment_label_score", ascending=False, inplace=True)

N = 5
for i, (idx, row) in enumerate(df_neg.iterrows()):
    if i < N:
        print(f"[Score {np.round(row['sentiment_label_score'], 3)}]:  ", row["sentences"])
        print("--------------------\n\n")
# Out:
# [Score 0.955]:   Component defects could make the Company's products unsafe and create a risk of environmental or property damage and personal injury.
# --------------------
#
#
# [Score 0.955]:   If our reputation or brand is damaged, our customers may refuse to continue shopping with us, potential employees may be unwilling to work for us, business partners may be discouraged from seeking future business dealings with us and, as a result, our operations and financial results may suffer.
# --------------------
#
#
# [Score 0.949]:   As a result, the Company's services may not perform as anticipated and may not meet customer expectations.
# --------------------
#
#
# [Score 0.948]:   Our products and services may contain undetected software errors, which could harm our business and operating results.
# --------------------
#
#
# [Score 0.947]:   Our software is highly complex and may contain undetected errors, defects or vulnerabilities, each of which could harm our business and financial performance.
# --------------------

# %%
# search for the sentences with the highest POSITIVE scores (LABEL_2)
df_pos = df.loc[df["sentiment_label"] == "LABEL_2"].copy()
df_pos.sort_values("sentiment_label_score", ascending=False, inplace=True)

N = 5
for i, (idx, row) in enumerate(df_pos.iterrows()):
    if i < N:
        print(f"[Score {np.round(row['sentiment_label_score'], 3)}]:  ", row["sentences"])
        print("--------------------\n")
# Out:
# [Score 0.97]:   Our brands, particularly the FOX brand, are among our most valuable assets.
# --------------------
#
# [Score 0.961]:   Our strong brands have significantly contributed to the success of our business.
# --------------------
#
# [Score 0.961]:   We believe that our brand image, brand awareness and reputation strengthen our relationship with consumers and contribute significantly to the success of our business.
# --------------------
#
# [Score 0.959]:   Our success will depend largely on our ability to remain a technology leader and continue to provide high-quality, innovative products and services that are truly useful and play a meaningful role in people's everyday lives.
# --------------------
#
# [Score 0.949]:   In addition, we believe that our corporate culture fosters innovation, creativity, and teamwork.
# --------------------
